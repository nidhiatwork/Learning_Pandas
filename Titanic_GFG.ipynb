# %%
# !pip install tensorflow-cpu==2.8
import numpy as np
import pandas as pd
import tensorflow as tf
import tflearn
# Out:
# Requirement already satisfied: tensorflow-cpu==2.8 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (24.3.7)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow-cpu==2.8) (1.62.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow-cpu==2.8) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow-cpu==2.8) (3.2.2)
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# # Import dataset

# %%
from tflearn.datasets import titanic
dataset = titanic.download_dataset('titanic_dataset.csv')
df = pd.read_csv(dataset)
df
# Out:
#       survived  pclass                                             name  \
# 0            1       1                    Allen, Miss. Elisabeth Walton
# 1            1       1                   Allison, Master. Hudson Trevor
# 2            0       1                     Allison, Miss. Helen Loraine
# 3            0       1             Allison, Mr. Hudson Joshua Creighton
# 4            0       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...     ...                                              ...
# 1304         0       3                             Zabour, Miss. Hileni
# 1305         0       3                            Zabour, Miss. Thamine
# 1306         0       3                        Zakarian, Mr. Mapriededer
# 1307         0       3                              Zakarian, Mr. Ortin
# 1308         0       3                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare
# 0     female  29.0000      0      0   24160  211.3375
# 1       male   0.9167      1      2  113781  151.5500
# 2     female   2.0000      1      2  113781  151.5500
# 3       male  30.0000      1      2  113781  151.5500
# 4     female  25.0000      1      2  113781  151.5500
# ...      ...      ...    ...    ...     ...       ...
# 1304  female  14.5000      1      0    2665   14.4542
# 1305  female   0.0000      1      0    2665   14.4542
# 1306    male  26.5000      0      0    2656    7.2250
# 1307    male  27.0000      0      0    2670    7.2250
# 1308    male  29.0000      0      0  315082    7.8750
#
# [1309 rows x 9 columns]

# %%
df.head()
# Out:
#    survived  pclass                                             name     sex  \
# 0         1       1                    Allen, Miss. Elisabeth Walton  female
# 1         1       1                   Allison, Master. Hudson Trevor    male
# 2         0       1                     Allison, Miss. Helen Loraine  female
# 3         0       1             Allison, Mr. Hudson Joshua Creighton    male
# 4         0       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare
# 0  29.0000      0      0   24160  211.3375
# 1   0.9167      1      2  113781  151.5500
# 2   2.0000      1      2  113781  151.5500
# 3  30.0000      1      2  113781  151.5500
# 4  25.0000      1      2  113781  151.5500

# %%
df.shape
# Out:
# (1309, 9)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare'],
#       dtype='object')

# %% [markdown]
# # Load CSV

# %%
from tflearn.data_utils import load_csv
data,labels = load_csv(dataset, target_column=0, categorical_labels=True, n_classes=2)
data[5]
# Out:
# ['1', 'Anderson, Mr. Harry', 'male', '48', '0', '0', '19952', '26.5500']

# %% [markdown]
# # Preprocess data
# Remove unwanted columns Name and Ticket.
# Convert sex column to 0 and 1

# %%
def preprocess(data, discarded_columns):
    for id in sorted(discarded_columns, reverse=True):
        print(id)
        [r.pop(id) for r in data]
    for i in range(len(data)):
        data[i][1] =1. if data[i][1]=='female' else 0.
    return np.array(data, dtype=np.float32)

# %%
discarded_columns = [1,6]
data=preprocess(data, discarded_columns)
# Out:
# 6
# 1

# %%
data
# Out:
# array([[  1.    ,   1.    ,  29.    ,   0.    ,   0.    , 211.3375],
#        [  1.    ,   0.    ,   0.9167,   1.    ,   2.    , 151.55  ],
#        [  1.    ,   1.    ,   2.    ,   1.    ,   2.    , 151.55  ],
#        ...,
#        [  3.    ,   0.    ,  26.5   ,   0.    ,   0.    ,   7.225 ],
#        [  3.    ,   0.    ,  27.    ,   0.    ,   0.    ,   7.225 ],
#        [  3.    ,   0.    ,  29.    ,   0.    ,   0.    ,   7.875 ]],
#       dtype=float32)

# %% [markdown]
# # Read Files

# %%
import pandas as pd
import seaborn as sns

# %%
# Load the Iris dataset from seaborn
df = sns.load_dataset('iris')

# %%
# Adding index to rows for explaining few operations later
custom_indices = ['index'+str(i) for i in range(1, len(df) + 1)]

# Assign custom string indices to the DataFrame
df.index = custom_indices

# %%
df
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index1            5.10         3.50          1.40         0.20     setosa
# index2            4.90         3.00          1.40         0.20     setosa
# index3            4.70         3.20          1.30         0.20     setosa
# index4            4.60         3.10          1.50         0.20     setosa
# index5            5.00         3.60          1.40         0.20     setosa
# ...                ...          ...           ...          ...        ...
# index146          6.70         3.00          5.20         2.30  virginica
# index147          6.30         2.50          5.00         1.90  virginica
# index148          6.50         3.00          5.20         2.00  virginica
# index149          6.20         3.40          5.40         2.30  virginica
# index150          5.90         3.00          5.10         1.80  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##Get basic info about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, index1 to index150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# ##Get shape of dataframe

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Get data types in dataframe

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
# Get only numeric data type columns
df.select_dtypes(include='number')
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...

# %% [markdown]
# ## Get head or tail of dataframe

# %%
df.head()
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# index1          5.10         3.50          1.40         0.20  setosa
# index2          4.90         3.00          1.40         0.20  setosa
# index3          4.70         3.20          1.30         0.20  setosa
# index4          4.60         3.10          1.50         0.20  setosa
# index5          5.00         3.60          1.40         0.20  setosa

# %%
df.tail()
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index146          6.70         3.00          5.20         2.30  virginica
# index147          6.30         2.50          5.00         1.90  virginica
# index148          6.50         3.00          5.20         2.00  virginica
# index149          6.20         3.40          5.40         2.30  virginica
# index150          5.90         3.00          5.10         1.80  virginica

# %% [markdown]
# # Read Columns and Rows

# %% [markdown]
# ## Iterate on all rows

# %%
for x in df.index:
    print(df.loc[x])
# Out:
# sepal_length      5.10
# sepal_width       3.50
# petal_length      1.40
# petal_width       0.20
# species         setosa
# Name: index1, dtype: object
# sepal_length      4.90
# sepal_width       3.00
# petal_length      1.40
# petal_width       0.20
# species         setosa
# Name: index2, dtype: object
# sepal_length      4.70
# sepal_width       3.20
# petal_length      1.30
# petal_width       0.20
# species         setosa
# Name: index3, dtype: object
# sepal_length      4.60
# sepal_width       3.10
# petal_length      1.50
# petal_width       0.20
# species         setosa
# Name: index4, dtype: object
# sepal_length      5.00
# sepal_width       3.60
# petal_length      1.40
# petal_width       0.20
# species         setosa
# Name: index5, dtype: object
# sepal_length      5.40
# sepal_width       3.90
# petal_length      1.70
# petal_width       0.40
# species         setosa
# Name: index6, dtype: object
# sepal_length      4.60
# sepal_width       3.40
# ...

# %% [markdown]
# ## Get one particular column

# %%
df['sepal_length']
# Out:
# index1     5.10
# index2     4.90
# index3     4.70
# index4     4.60
# index5     5.00
#            ...
# index146   6.70
# index147   6.30
# index148   6.50
# index149   6.20
# index150   5.90
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# ## loc function: Get data by labels and boolean conditions

# %% [markdown]
# ### loc: Row label examples

# %%
df.loc['index4']
# Out:
# sepal_length      4.60
# sepal_width       3.10
# petal_length      1.50
# petal_width       0.20
# species         setosa
# Name: index4, dtype: object

# %%
df.loc['index1':'index4']
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# index1          5.10         3.50          1.40         0.20  setosa
# index2          4.90         3.00          1.40         0.20  setosa
# index3          4.70         3.20          1.30         0.20  setosa
# index4          4.60         3.10          1.50         0.20  setosa

# %% [markdown]
# ### loc: Column label examples

# %%
df.loc['index1':'index4', ['sepal_length', 'sepal_width']]
# Out:
#         sepal_length  sepal_width
# index1          5.10         3.50
# index2          4.90         3.00
# index3          4.70         3.20
# index4          4.60         3.10

# %% [markdown]
# ### loc: Boolean condition examples

# %%
df.loc[df['sepal_width']>=3.0]
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index1            5.10         3.50          1.40         0.20     setosa
# index2            4.90         3.00          1.40         0.20     setosa
# index3            4.70         3.20          1.30         0.20     setosa
# index4            4.60         3.10          1.50         0.20     setosa
# index5            5.00         3.60          1.40         0.20     setosa
# ...                ...          ...           ...          ...        ...
# index145          6.70         3.30          5.70         2.50  virginica
# index146          6.70         3.00          5.20         2.30  virginica
# index148          6.50         3.00          5.20         2.00  virginica
# index149          6.20         3.40          5.40         2.30  virginica
# index150          5.90         3.00          5.10         1.80  virginica
#
# [93 rows x 5 columns]

# %% [markdown]
# ## iloc: Get data by indices of rows and columns (note: last index is excluded while defining range using :)

# %% [markdown]
# ### iloc: Row index examples

# %%
df.iloc[4]
# Out:
# sepal_length      5.00
# sepal_width       3.60
# petal_length      1.40
# petal_width       0.20
# species         setosa
# Name: index5, dtype: object

# %%
df.iloc[1:4]
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# index2          4.90         3.00          1.40         0.20  setosa
# index3          4.70         3.20          1.30         0.20  setosa
# index4          4.60         3.10          1.50         0.20  setosa

# %% [markdown]
# ### iloc: Column index examples

# %%
df.iloc[1:4, 2]
# Out:
# index2   1.40
# index3   1.30
# index4   1.50
# Name: petal_length, dtype: float64

# %% [markdown]
# # Filtering data

# %% [markdown]
# ### Filtering: Based on comparison

# %%
df[df['sepal_width']>3.0]
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index1            5.10         3.50          1.40         0.20     setosa
# index3            4.70         3.20          1.30         0.20     setosa
# index4            4.60         3.10          1.50         0.20     setosa
# index5            5.00         3.60          1.40         0.20     setosa
# index6            5.40         3.90          1.70         0.40     setosa
# ...                ...          ...           ...          ...        ...
# index141          6.70         3.10          5.60         2.40  virginica
# index142          6.90         3.10          5.10         2.30  virginica
# index144          6.80         3.20          5.90         2.30  virginica
# index145          6.70         3.30          5.70         2.50  virginica
# index149          6.20         3.40          5.40         2.30  virginica
#
# [67 rows x 5 columns]

# %% [markdown]
# ### Filtering: Based on values from a list

# %%
df[df['sepal_width'].isin([3.0,4.0])]
# Out:
#           sepal_length  sepal_width  petal_length  petal_width     species
# index2            4.90         3.00          1.40         0.20      setosa
# index13           4.80         3.00          1.40         0.10      setosa
# index14           4.30         3.00          1.10         0.10      setosa
# index15           5.80         4.00          1.20         0.20      setosa
# index26           5.00         3.00          1.60         0.20      setosa
# index39           4.40         3.00          1.30         0.20      setosa
# index46           4.80         3.00          1.40         0.30      setosa
# index62           5.90         3.00          4.20         1.50  versicolor
# index67           5.60         3.00          4.50         1.50  versicolor
# index76           6.60         3.00          4.40         1.40  versicolor
# index78           6.70         3.00          5.00         1.70  versicolor
# ...

# %% [markdown]
# ### Filtering: Based on string containment

# %%
df[df['species'].str.contains('vir')]
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index101          6.30         3.30          6.00         2.50  virginica
# index102          5.80         2.70          5.10         1.90  virginica
# index103          7.10         3.00          5.90         2.10  virginica
# index104          6.30         2.90          5.60         1.80  virginica
# index105          6.50         3.00          5.80         2.20  virginica
# index106          7.60         3.00          6.60         2.10  virginica
# index107          4.90         2.50          4.50         1.70  virginica
# index108          7.30         2.90          6.30         1.80  virginica
# index109          6.70         2.50          5.80         1.80  virginica
# index110          7.20         3.60          6.10         2.50  virginica
# index111          6.50         3.20          5.10         2.00  virginica
# index112          6.40         2.70          5.30         1.90  virginica
# ...

# %% [markdown]
# ### Filtering: Based on filter function
# If axis=0, it selects the specified labels from rows. If axis=1 (by default it is one) then it selects specified labels from columns

# %% [markdown]
# #### Axis=1 example
# default case is axis=1

# %%
df.filter(items = ['petal_width', 'species'])
# Out:
#           petal_width    species
# index1           0.20     setosa
# index2           0.20     setosa
# index3           0.20     setosa
# index4           0.20     setosa
# index5           0.20     setosa
# ...               ...        ...
# index146         2.30  virginica
# index147         1.90  virginica
# index148         2.00  virginica
# index149         2.30  virginica
# index150         1.80  virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Axis=0 example

# %%
df.filter(items=['index1', 'index3'], axis=0)
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# index1          5.10         3.50          1.40         0.20  setosa
# index3          4.70         3.20          1.30         0.20  setosa

# %% [markdown]
# #### using Like in filter

# %%
df.filter(like = "index1", axis=0)
# Out:
#           sepal_length  sepal_width  petal_length  petal_width    species
# index1            5.10         3.50          1.40         0.20     setosa
# index10           4.90         3.10          1.50         0.10     setosa
# index11           5.40         3.70          1.50         0.20     setosa
# index12           4.80         3.40          1.60         0.20     setosa
# index13           4.80         3.00          1.40         0.10     setosa
# ...                ...          ...           ...          ...        ...
# index146          6.70         3.00          5.20         2.30  virginica
# index147          6.30         2.50          5.00         1.90  virginica
# index148          6.50         3.00          5.20         2.00  virginica
# index149          6.20         3.40          5.40         2.30  virginica
# index150          5.90         3.00          5.10         1.80  virginica
#
# [62 rows x 5 columns]

# %% [markdown]
# ## Sorting data

# %%
df[df['sepal_width']>3].sort_values(by=['sepal_length', 'petal_length'], ascending=False)
# Out:
#           sepal_length  sepal_width  petal_length  petal_width     species
# index132          7.90         3.80          6.40         2.00   virginica
# index118          7.70         3.80          6.70         2.20   virginica
# index110          7.20         3.60          6.10         2.50   virginica
# index126          7.20         3.20          6.00         1.80   virginica
# index51           7.00         3.20          4.70         1.40  versicolor
# ...                ...          ...           ...          ...         ...
# index4            4.60         3.10          1.50         0.20      setosa
# index7            4.60         3.40          1.40         0.30      setosa
# index48           4.60         3.20          1.40         0.20      setosa
# index23           4.60         3.60          1.00         0.20      setosa
# index43           4.40         3.20          1.30         0.20      setosa
#
# [67 rows x 5 columns]

# %% [markdown]
# # Indexing data

# %%
# Reset the index back to integers
df.reset_index(inplace=True)
df
# Out:
#         index  sepal_length  sepal_width  petal_length  petal_width    species
# 0      index1          5.10         3.50          1.40         0.20     setosa
# 1      index2          4.90         3.00          1.40         0.20     setosa
# 2      index3          4.70         3.20          1.30         0.20     setosa
# 3      index4          4.60         3.10          1.50         0.20     setosa
# 4      index5          5.00         3.60          1.40         0.20     setosa
# ..        ...           ...          ...           ...          ...        ...
# 145  index146          6.70         3.00          5.20         2.30  virginica
# 146  index147          6.30         2.50          5.00         1.90  virginica
# 147  index148          6.50         3.00          5.20         2.00  virginica
# 148  index149          6.20         3.40          5.40         2.30  virginica
# 149  index150          5.90         3.00          5.10         1.80  virginica
#
# [150 rows x 6 columns]

# %%
df.set_index(['index', 'species'], inplace=True)
df
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width
# index    species
# index1   setosa             5.10         3.50          1.40         0.20
# index2   setosa             4.90         3.00          1.40         0.20
# index3   setosa             4.70         3.20          1.30         0.20
# index4   setosa             4.60         3.10          1.50         0.20
# index5   setosa             5.00         3.60          1.40         0.20
# ...                          ...          ...           ...          ...
# index146 virginica          6.70         3.00          5.20         2.30
# index147 virginica          6.30         2.50          5.00         1.90
# index148 virginica          6.50         3.00          5.20         2.00
# index149 virginica          6.20         3.40          5.40         2.30
# index150 virginica          5.90         3.00          5.10         1.80
#
# [150 rows x 4 columns]

# %%
df.sort_index(ascending=False)
# Out:
#                      sepal_length  sepal_width  petal_length  petal_width
# index    species
# index99  versicolor          5.10         2.50          3.00         1.10
# index98  versicolor          6.20         2.90          4.30         1.30
# index97  versicolor          5.70         2.90          4.20         1.30
# index96  versicolor          5.70         3.00          4.20         1.20
# index95  versicolor          5.60         2.70          4.20         1.30
# ...                           ...          ...           ...          ...
# index102 virginica           5.80         2.70          5.10         1.90
# index101 virginica           6.30         3.30          6.00         2.50
# index100 versicolor          5.70         2.80          4.10         1.30
# index10  setosa              4.90         3.10          1.50         0.10
# index1   setosa              5.10         3.50          1.40         0.20
#
# [150 rows x 4 columns]

# %% [markdown]
# # Grouping and Aggregating

# %% [markdown]
# ## Group By (One column)

# %%
# reset to original data
df = sns.load_dataset('iris')

# %%
group_by_species = df.groupby('species')

# %%
group_by_species.mean()
# It calculates mean of only the numeric columns of the dataframe grouped by the mentioned column
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              5.01         3.43          1.46         0.25
# versicolor          5.94         2.77          4.26         1.33
# virginica           6.59         2.97          5.55         2.03

# %%
group_by_species.count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
group_by_species.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa              4.30         2.30          1.00         0.10
# versicolor          4.90         2.00          3.00         1.00
# virginica           4.90         2.20          4.50         1.40

# %%
group_by_species.sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa            250.30       171.40         73.10        12.30
# versicolor        296.80       138.50        213.00        66.30
# virginica         329.40       148.70        277.60       101.30

# %% [markdown]
# ## Group By mutiple columns

# %%
group_by_species_sepal_length = df.groupby(['species', 'sepal_length'])
group_by_species_sepal_length

# %%
group_by_species_sepal_length.count()
# Out:
#                          sepal_width  petal_length  petal_width
# species    sepal_length
# setosa     4.30                    1             1            1
#            4.40                    3             3            3
#            4.50                    1             1            1
#            4.60                    4             4            4
#            4.70                    2             2            2
#            4.80                    5             5            5
#            4.90                    4             4            4
#            5.00                    8             8            8
#            5.10                    8             8            8
#            5.20                    3             3            3
#            5.30                    1             1            1
#            5.40                    5             5            5
#            5.50                    2             2            2
# ...

# %% [markdown]
# ## Aggregation
# Perform above operations like sum, mean etc on particular columns instead of all

# %%
group_by_species.agg({'sepal_length': ['mean', 'sum', 'count', 'max'], 'sepal_width': ['sum', 'count', 'max']})
# Out:
#            sepal_length                   sepal_width
#                    mean    sum count  max         sum count  max
# species
# setosa             5.01 250.30    50 5.80      171.40    50 4.40
# versicolor         5.94 296.80    50 7.00      138.50    50 3.40
# virginica          6.59 329.40    50 7.90      148.70    50 3.80

# %%
group_by_species_sepal_length.agg({'sepal_width': ['count', 'sum', 'max']})
# Out:
#                         sepal_width
#                               count   sum  max
# species    sepal_length
# setosa     4.30                   1  3.00 3.00
#            4.40                   3  9.10 3.20
#            4.50                   1  2.30 2.30
#            4.60                   4 13.30 3.60
#            4.70                   2  6.40 3.20
#            4.80                   5 15.90 3.40
#            4.90                   4 12.80 3.60
#            5.00                   8 26.90 3.60
#            5.10                   8 28.80 3.80
#            5.20                   3 11.00 4.10
#            5.30                   1  3.70 3.70
#            5.40                   5 18.30 3.90
#            5.50                   2  7.70 4.20
#            5.70                   2  8.20 4.40
#            5.80                   1  4.00 4.00
# versicolor 4.90                   1  2.40 2.40
#            5.00                   2  4.30 2.30
#            5.10                   1  2.50 2.50
# ...

# %% [markdown]
# ## Describe()

# %%
group_by_species.describe()
# Out:
#            sepal_length                                    sepal_width       \
#                   count mean  std  min  25%  50%  75%  max       count mean
# species
# setosa            50.00 5.01 0.35 4.30 4.80 5.00 5.20 5.80       50.00 3.43
# versicolor        50.00 5.94 0.52 4.90 5.60 5.90 6.30 7.00       50.00 2.77
# virginica         50.00 6.59 0.64 4.90 6.22 6.50 6.90 7.90       50.00 2.97
#
#             ... petal_length      petal_width                                \
#             ...          75%  max       count mean  std  min  25%  50%  75%
# species     ...
# setosa      ...         1.58 1.90       50.00 0.25 0.11 0.10 0.20 0.20 0.30
# versicolor  ...         4.60 5.10       50.00 1.33 0.20 1.00 1.20 1.30 1.50
# virginica   ...         5.88 6.90       50.00 2.03 0.27 1.40 1.80 2.00 2.30
#
#
#             max
# species
# setosa     0.60
# versicolor 1.80
# virginica  2.50
#
# [3 rows x 32 columns]

# %% [markdown]
# # Merge Dataframes

# %% [markdown]
# ### Inner merge

# %% [markdown]
# #### Merge on single column

# %%
# Creating the first DataFrame
data1 = {
    'FellowshipID': [101, 102, 103, 104, 105],
    'FirstName': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'Skills': ['Python', 'Java', 'C++', 'Python', 'Java']
}

df1 = pd.DataFrame(data1)
df1
# Out:
#    FellowshipID FirstName  Skills
# 0           101     Alice  Python
# 1           102       Bob    Java
# 2           103   Charlie     C++
# 3           104     David  Python
# 4           105      Emma    Java

# %%
# Creating the second DataFrame
data2 = {
    'FellowshipID': [101, 102, 105, 106, 107],
    'FirstName': ['Alice', 'Bob', 'Emma', 'Frank', 'Grace'],
    'Age': [25, 30, 28, 35, 29]
}

df2 = pd.DataFrame(data2)
df2
# Out:
#    FellowshipID FirstName  Age
# 0           101     Alice   25
# 1           102       Bob   30
# 2           105      Emma   28
# 3           106     Frank   35
# 4           107     Grace   29

# %%
df1.merge(df2, how='inner', on='FellowshipID') #shows common rows
# Out:
#    FellowshipID FirstName_x  Skills FirstName_y  Age
# 0           101       Alice  Python       Alice   25
# 1           102         Bob    Java         Bob   30
# 2           105        Emma    Java        Emma   28

# %% [markdown]
# #### Merge on multiple columns

# %%
df1.merge(df2, how='inner', on=['FellowshipID', 'FirstName']) #shows common rows
# Out:
#    FellowshipID FirstName  Skills  Age
# 0           101     Alice  Python   25
# 1           102       Bob    Java   30
# 2           105      Emma    Java   28

# %% [markdown]
# ### Outer merge

# %%
df1.merge(df2, how='outer') #all rows
# Out:
#    FellowshipID FirstName  Skills   Age
# 0           101     Alice  Python 25.00
# 1           102       Bob    Java 30.00
# 2           103   Charlie     C++   NaN
# 3           104     David  Python   NaN
# 4           105      Emma    Java 28.00
# 5           106     Frank     NaN 35.00
# 6           107     Grace     NaN 29.00

# %% [markdown]
# ### Left merge

# %%
df1.merge(df2, how='left')
# Out:
#    FellowshipID FirstName  Skills   Age
# 0           101     Alice  Python 25.00
# 1           102       Bob    Java 30.00
# 2           103   Charlie     C++   NaN
# 3           104     David  Python   NaN
# 4           105      Emma    Java 28.00

# %% [markdown]
# ### Right merge

# %%
df1.merge(df2, how='right')
# Out:
#    FellowshipID FirstName  Skills  Age
# 0           101     Alice  Python   25
# 1           102       Bob    Java   30
# 2           105      Emma    Java   28
# 3           106     Frank     NaN   35
# 4           107     Grace     NaN   29

# %% [markdown]
# ### Cross merge

# %%
df1.merge(df2, how='cross')
# Out:
#     FellowshipID_x FirstName_x  Skills  FellowshipID_y FirstName_y  Age
# 0              101       Alice  Python             101       Alice   25
# 1              101       Alice  Python             102         Bob   30
# 2              101       Alice  Python             105        Emma   28
# 3              101       Alice  Python             106       Frank   35
# 4              101       Alice  Python             107       Grace   29
# 5              102         Bob    Java             101       Alice   25
# 6              102         Bob    Java             102         Bob   30
# 7              102         Bob    Java             105        Emma   28
# 8              102         Bob    Java             106       Frank   35
# 9              102         Bob    Java             107       Grace   29
# 10             103     Charlie     C++             101       Alice   25
# 11             103     Charlie     C++             102         Bob   30
# ...

# %% [markdown]
# ## Join Dataframes

# %%
# Dont use it this way. Output is less understandable
df1.join(df2, on='FellowshipID', how='outer', lsuffix='_Left', rsuffix='_Right')
# Out:
#       FellowshipID  FellowshipID_Left FirstName_Left  Skills  \
# 0.00           101             101.00          Alice  Python
# 1.00           102             102.00            Bob    Java
# 2.00           103             103.00        Charlie     C++
# 3.00           104             104.00          David  Python
# 4.00           105             105.00           Emma    Java
# NaN              0                NaN            NaN     NaN
# NaN              1                NaN            NaN     NaN
# NaN              2                NaN            NaN     NaN
# NaN              3                NaN            NaN     NaN
# NaN              4                NaN            NaN     NaN
#
#       FellowshipID_Right FirstName_Right   Age
# 0.00                 NaN             NaN   NaN
# 1.00                 NaN             NaN   NaN
# 2.00                 NaN             NaN   NaN
# 3.00                 NaN             NaN   NaN
# 4.00                 NaN             NaN   NaN
# ...

# %%
df3 = df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'), lsuffix='_Left', rsuffix='_Right')
df3
# Out:
#              FirstName_Left  Skills FirstName_Right   Age
# FellowshipID
# 101                   Alice  Python           Alice 25.00
# 102                     Bob    Java             Bob 30.00
# 103                 Charlie     C++             NaN   NaN
# 104                   David  Python             NaN   NaN
# 105                    Emma    Java            Emma 28.00

# %% [markdown]
# ## Concatenate Dataframes

# %% [markdown]
# ### Concatenate with all columns

# %%
pd.concat([df1, df2])
# Out:
#    FellowshipID FirstName  Skills   Age
# 0           101     Alice  Python   NaN
# 1           102       Bob    Java   NaN
# 2           103   Charlie     C++   NaN
# 3           104     David  Python   NaN
# 4           105      Emma    Java   NaN
# 0           101     Alice     NaN 25.00
# 1           102       Bob     NaN 30.00
# 2           105      Emma     NaN 28.00
# 3           106     Frank     NaN 35.00
# 4           107     Grace     NaN 29.00

# %% [markdown]
# ### Concatenate as well as inner join

# %%
pd.concat([df1, df2], join='inner')
# Out:
#    FellowshipID FirstName
# 0           101     Alice
# 1           102       Bob
# 2           103   Charlie
# 3           104     David
# 4           105      Emma
# 0           101     Alice
# 1           102       Bob
# 2           105      Emma
# 3           106     Frank
# 4           107     Grace

# %% [markdown]
# ### Concatenate as well as outer join

# %% [markdown]
# #### Stack rows on top of each other

# %%
pd.concat([df1, df2], join='outer', axis=0)
# Out:
#    FellowshipID FirstName  Skills   Age
# 0           101     Alice  Python   NaN
# 1           102       Bob    Java   NaN
# 2           103   Charlie     C++   NaN
# 3           104     David  Python   NaN
# 4           105      Emma    Java   NaN
# 0           101     Alice     NaN 25.00
# 1           102       Bob     NaN 30.00
# 2           105      Emma     NaN 28.00
# 3           106     Frank     NaN 35.00
# 4           107     Grace     NaN 29.00

# %% [markdown]
# #### Stack columns on top of each other

# %%
pd.concat([df1, df2], join='outer', axis=1)
# Out:
#    FellowshipID FirstName  Skills  FellowshipID FirstName  Age
# 0           101     Alice  Python           101     Alice   25
# 1           102       Bob    Java           102       Bob   30
# 2           103   Charlie     C++           105      Emma   28
# 3           104     David  Python           106     Frank   35
# 4           105      Emma    Java           107     Grace   29

# %% [markdown]
# # Visualize Data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'Date': ['2024-03-01', '2024-03-02', '2024-03-03', '2024-03-04', '2024-03-05'],
    'Flavour Rating': [4.123456, 5.654321, 3.987654, 4.555555, 5.111111],
    'Texture Rating': [3.987654, 4.111111, 5.333333, 4.222222, 3.888888],
    'Overall Rating': [4.234567, 4.888888, 4.011111, 4.333333, 4.666666]
}

ratings_df = pd.DataFrame(data)
ratings_df = ratings_df.set_index('Date')
ratings_df
# Out:
#             Flavour Rating  Texture Rating  Overall Rating
# Date
# 2024-03-01            4.12            3.99            4.23
# 2024-03-02            5.65            4.11            4.89
# 2024-03-03            3.99            5.33            4.01
# 2024-03-04            4.56            4.22            4.33
# 2024-03-05            5.11            3.89            4.67

# %% [markdown]
# ## Optional: Set style of plots

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %% [markdown]
# ## Draw line plots

# %%
ratings_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ratings_df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Draw subplots

# %%
ratings_df.plot(kind = 'line', subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %% [markdown]
# ### Put title on plot

# %%
ratings_df.plot(kind = 'line', title='Ice Cream ratings')
# Out:
# <Axes: title={'center': 'Ice Cream ratings'}, xlabel='Date'>

# %% [markdown]
# ### Put labels on x and y axis

# %%
ratings_df.plot(kind = 'line', title='Ice Cream ratings', xlabel='Daily ratings', ylabel='Scores')
# Out:
# <Axes: title={'center': 'Ice Cream ratings'}, xlabel='Daily ratings', ylabel='Scores'>

# %% [markdown]
# ## Draw bar plots

# %%
ratings_df.plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Pick one column for plotting

# %%
ratings_df['Flavour Rating'].plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Make it horizontal instead of vertical

# %%
ratings_df.plot.barh()
# Out:
# <Axes: ylabel='Date'>

# %% [markdown]
# ## Draw scatter plots

# %%
ratings_df.plot.scatter(x = 'Texture Rating', y='Overall Rating')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# ### Set size and color

# %%
ratings_df.plot.scatter(x = 'Texture Rating', y='Overall Rating', s=200, c='Red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %% [markdown]
# ## Draw histograms

# %%
ratings_df.plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Draw Box plots

# %%
ratings_df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## Draw Area plots

# %%
ratings_df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Change plot size

# %%
ratings_df.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Draw pie chart

# %%
ratings_df.plot.pie(y='Flavour Rating', figsize=(10,10))
# Out:
# <Axes: ylabel='Flavour Rating'>

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_excel('/content/drive/MyDrive/GenAI/Pandas/data/Customer Call List.xlsx')
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %% [markdown]
# ## Iterate on all rows of a DataFrame

# %%
for x in df.index:
    print(df.iloc[x]) #since iloc works on integer index
# Out:
# CustomerID                            1001
# First_Name                           Frodo
# Last_Name                          Baggins
# Phone_Number                  123-545-5421
# Address              123 Shire Lane, Shire
# Paying Customer                        Yes
# Do_Not_Contact                          No
# Not_Useful_Column                     True
# Name: 0, dtype: object
# CustomerID                          1002
# First_Name                          Abed
# Last_Name                          Nadir
# Phone_Number                123/643/9775
# Address              93 West Main Street
# Paying Customer                       No
# Do_Not_Contact                       Yes
# Not_Useful_Column                  False
# Name: 1, dtype: object
# CustomerID                         1003
# First_Name                       Walter
# Last_Name                        /White
# Phone_Number                 7066950392
# Address              298 Drugs Driveway
# ...

# %% [markdown]
# ## Drop duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# ## Drop Rows

# %%
df = df.drop([14,15]) #14 and 15 are index
df
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 0         1001      Frodo    Baggins  123-545-5421
# 1         1002       Abed      Nadir  123/643/9775
# 2         1003     Walter     /White    7066950392
# 3         1004     Dwight    Schrute  123-543-2345
# 4         1005        Jon       Snow  876|678|3469
# 5         1006        Ron    Swanson  304-762-2467
# 6         1007       Jeff     Winger           NaN
# 7         1008   Sherlock     Holmes  876|678|3469
# 8         1009    Gandalf        NaN           N/a
# 9         1010      Peter     Parker  123-545-5421
# 10        1011    Samwise     Gamgee           NaN
# 11        1012      Harry  ...Potter    7066950392
# 12        1013        Don     Draper  123-543-2345
# 13        1014     Leslie      Knope  876|678|3469
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# ...

# %% [markdown]
# ## Drop columns

# %%
df = df.drop(columns = ["Not_Useful_Column"])
df
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 0         1001      Frodo    Baggins  123-545-5421
# 1         1002       Abed      Nadir  123/643/9775
# 2         1003     Walter     /White    7066950392
# 3         1004     Dwight    Schrute  123-543-2345
# 4         1005        Jon       Snow  876|678|3469
# 5         1006        Ron    Swanson  304-762-2467
# 6         1007       Jeff     Winger           NaN
# 7         1008   Sherlock     Holmes  876|678|3469
# 8         1009    Gandalf        NaN           N/a
# 9         1010      Peter     Parker  123-545-5421
# 10        1011    Samwise     Gamgee           NaN
# 11        1012      Harry  ...Potter    7066950392
# 12        1013        Don     Draper  123-543-2345
# 13        1014     Leslie      Knope  876|678|3469
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# ...

# %% [markdown]
# ## Left/Right strip characters from particular column data

# %%
df["Last_Name"] = df["Last_Name"].str.lstrip("...")
df["Last_Name"] = df["Last_Name"].str.lstrip("/")
df["Last_Name"] = df["Last_Name"].str.rstrip("_")
df
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 0         1001      Frodo    Baggins  123-545-5421
# 1         1002       Abed      Nadir  123/643/9775
# 2         1003     Walter      White    7066950392
# 3         1004     Dwight    Schrute  123-543-2345
# 4         1005        Jon       Snow  876|678|3469
# 5         1006        Ron    Swanson  304-762-2467
# 6         1007       Jeff     Winger           NaN
# 7         1008   Sherlock     Holmes  876|678|3469
# 8         1009    Gandalf        NaN           N/a
# 9         1010      Peter     Parker  123-545-5421
# 10        1011    Samwise     Gamgee           NaN
# 11        1012      Harry     Potter    7066950392
# 12        1013        Don     Draper  123-543-2345
# 13        1014     Leslie      Knope  876|678|3469
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# ...

# %% [markdown]
# ## Left/Right string using regex

# %%
df = pd.read_excel('/content/drive/MyDrive/GenAI/Pandas/data/Customer Call List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'] = df['Last_Name'].str.strip("123._/")
df['Last_Name']
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# 20     Skywalker
# Name: Last_Name, dtype: object

# %% [markdown]
# ## Lambda

# %% [markdown]
# ### Convert phone numbers to this format 123-456-7890

# %%
# First clean the phone numbers column
df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '') #everything except a-z, A-Z, 9-9
df
# Out:
# <ipython-input-281-8055452886be>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '') #everything except a-z, A-Z, 9-9
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee          NaN
# 11        1012      Harry      Potter          NaN
# 12        1013        Don      Draper   1235432345
# ...

# %%
# Another is using lambda
# First convert phone number column to string
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))

# Then
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:10])
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2            nan--
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6            nan--
# 7     876-678-3469
# 8             Na--
# 9     123-545-5421
# 10           nan--
# 11           nan--
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17           nan--
# 18            Na--
# 19    876-678-3469
# 20    876-678-3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# ## Remove nan-- or NA-- from phone numbers

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--', '')
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6
# 7     876-678-3469
# 8
# 9     123-545-5421
# 10
# 11
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17
# 18
# 19    876-678-3469
# 20    876-678-3469
# Name: Phone_Number, dtype: object

# %% [markdown]
# ## Splitting

# %%
df['Address'].str.split(',', 2)
# Out:
# <ipython-input-284-a98c2f005727>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df['Address'].str.split(',', 2)
# 0                      [123 Shire Lane,  Shire]
# 1                         [93 West Main Street]
# 2                          [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania,  18503]
# 4                            [123 Dragons Road]
# 5                            [768 City Parkway]
# 6                           [1209 South Street]
# 7                               [98 Clue Drive]
# 8                            [123 Middle Earth]
# 9                 [25th Main Street,  New York]
# 10                     [612 Shire Lane,  Shire]
# 11                       [2394 Hogwarts Avenue]
# 12                           [2039 Main Street]
# 13                           [343 City Parkway]
# 14                              [214 HR Avenue]
# ...

# %% [markdown]
# ### See result in columns properly

# %%
df['Address'].str.split(',', 2, expand=True)
# Out:
# <ipython-input-285-6b005b3fc4fe>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df['Address'].str.split(',', 2, expand=True)
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# ...

# %% [markdown]
# ### Assign the result to street address, state and zip code

# %%
df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', 2, expand=True)
# Out:
# <ipython-input-286-71adc2b0fa53>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[["Street_Address", "State", "Zip_Code"]] = df['Address'].str.split(',', 2, expand=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %% [markdown]
# ## Replace

# %% [markdown]
# ### Replace Yes/No with Y/N

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes", "Y")
df["Paying Customer"] = df["Paying Customer"].str.replace("No", "N")

df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes", "Y")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No", "N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %% [markdown]
# ### Replace N/a or NAN with empty

# %%
df = df.replace('N/a', '')
df = df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %% [markdown]
# ## Drop columns based on condition

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"]=='Y':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
# 20        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"]=='':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
# 20        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# ...

# %% [markdown]
# ## Another way to drop null values from Phone number column

# %%
df = df.dropna(subset="Phone_Number")

# %% [markdown]
# ## Reset index finally

# %%
df = df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1005        Jon        Snow  876-678-3469
# 2         1008   Sherlock      Holmes  876-678-3469
# 3         1010      Peter      Parker  123-545-5421
# 4         1013        Don      Draper  123-543-2345
# 5         1014     Leslie       Knope  876-678-3469
# 6         1015       Toby  Flenderson  304-762-2467
# 7         1016        Ron     Weasley  123-545-5421
# 8         1017   Michael        Scott  123-643-9775
# 9         1020     Anakin   Skywalker  876-678-3469
# 10        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1                 123 Dragons Road               Y              N
# 2                    98 Clue Drive               N              N
# 3       25th Main Street, New York               Y              N
# ...

# %% [markdown]
# # EDA: Exploratory data analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/GenAI/Pandas/data/world_population.csv')
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %% [markdown]
# ## Set better readability for float data

# %%
pd.set_option('display.float_format', lambda x: '%.2f' %x)

# %% [markdown]
# ## Describe and Info function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %% [markdown]
# ## Check null value count

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# ## Check unique value count

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %% [markdown]
# ## Top population values for 2022 Population column

# %%
df.sort_values(by="2022 Population", ascending=False).head()
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 92     1417173173.00    1396387127.00    1322866505.00    1240613620.00
# 221     338289857.00     335942003.00     324607776.00     311182845.00
# 93      275501339.00     271857970.00     259091970.00     244016173.00
# 156     235824862.00     227196741.00     210969298.00     194454498.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41     1264099069.00    1153704252.00     982372466.00     822534450.00
# ...

# %% [markdown]
# ## Correlation in data

# %%
df.corr()
# Out:
# <ipython-input-302-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# ...

# %% [markdown]
# ### Correlation using heatmap

# %%
sns.heatmap(df.corr(), annot=True)
plt.rcParams['figure.figsize'] = (20,7)
plt.show()
# Out:
# <ipython-input-303-f304fec9c8bf>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## Use case: Check which one continent has grown faster

# %% [markdown]
# ### Get continents whose mean 2022 population has been high

# %%
df2 = df.groupby('Continent')['1970 Population',
 '1980 Population',
 '1990 Population',
 '2000 Population',
 '2010 Population',
 '2015 Population',
 '2020 Population',
 '2022 Population'].mean().sort_values('2022 Population', ascending=False)
df2
# Out:
# <ipython-input-312-0978d013a7ac>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2 = df.groupby('Continent')['1970 Population',
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# ...

# %% [markdown]
# ### Line Plot for above data

# %%
df2.plot()
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### Transpose row and columns

# %%
df3 = df2.transpose()
df3
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
#
# Continent        North America    Oceania
# 1970 Population     7885865.15  846968.26
# 1980 Population     9207334.03  996532.17
# 1990 Population    10531660.62 1162774.87
# 2000 Population    12151739.60 1357512.09
# 2010 Population    13568016.28 1613163.65
# 2015 Population    14259596.25 1756664.48
# 2020 Population    14855914.82 1910148.96
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
x = ['2022 Population',
       '2020 Population', '2015 Population', '2010 Population',
       '2000 Population', '1990 Population', '1980 Population',
       '1970 Population']
x.reverse()
x
# Out:
# ['1970 Population',
#  '1980 Population',
#  '1990 Population',
#  '2000 Population',
#  '2010 Population',
#  '2015 Population',
#  '2020 Population',
#  '2022 Population']

# %% [markdown]
# ## Explore data using BoxPlot

# %%
df.boxplot(figsize=(25,5))
# Out:
# <Axes: >
